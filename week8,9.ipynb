# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('./Desktop/iris.csv')

# %%
df.shape
# Out:
# (150, 5)

# %%
df
# Out:
#      sepal_len  sepal_width  petal_len  petal_width         species
# 0          5.1          3.5        1.4          0.2     Iris-setosa
# 1          4.9          3.0        1.4          0.2     Iris-setosa
# 2          4.7          3.2        1.3          0.2     Iris-setosa
# 3          4.6          3.1        1.5          0.2     Iris-setosa
# 4          5.0          3.6        1.4          0.2     Iris-setosa
# 5          5.4          3.9        1.7          0.4     Iris-setosa
# 6          4.6          3.4        1.4          0.3     Iris-setosa
# 7          5.0          3.4        1.5          0.2     Iris-setosa
# 8          4.4          2.9        1.4          0.2     Iris-setosa
# 9          4.9          3.1        1.5          0.1     Iris-setosa
# 10         5.4          3.7        1.5          0.2     Iris-setosa
# 11         4.8          3.4        1.6          0.2     Iris-setosa
# 12         4.8          3.0        1.4          0.1     Iris-setosa
# ...

# %%
avgpl=df['petal_len'].mean()

# %%
df.mean()
# Out:
# sepal_len      5.843333
# sepal_width    3.054000
# petal_len      3.758667
# petal_width    1.198667
# dtype: float64

# %%
df.std()
# Out:
# sepal_len      0.828066
# sepal_width    0.433594
# petal_len      1.764420
# petal_width    0.763161
# dtype: float64

# %%
df
# Out:
#      sepal_len  sepal_width  petal_len  petal_width         species
# 0          5.1          3.5        1.4          0.2     Iris-setosa
# 1          4.9          3.0        1.4          0.2     Iris-setosa
# 2          4.7          3.2        1.3          0.2     Iris-setosa
# 3          4.6          3.1        1.5          0.2     Iris-setosa
# 4          5.0          3.6        1.4          0.2     Iris-setosa
# 5          5.4          3.9        1.7          0.4     Iris-setosa
# 6          4.6          3.4        1.4          0.3     Iris-setosa
# 7          5.0          3.4        1.5          0.2     Iris-setosa
# 8          4.4          2.9        1.4          0.2     Iris-setosa
# 9          4.9          3.1        1.5          0.1     Iris-setosa
# 10         5.4          3.7        1.5          0.2     Iris-setosa
# 11         4.8          3.4        1.6          0.2     Iris-setosa
# 12         4.8          3.0        1.4          0.1     Iris-setosa
# ...

# %%
df[df.petal_len > 1.5 * avgpl]
# Out:
#      sepal_len  sepal_width  petal_len  petal_width         species
# 100        6.3          3.3        6.0          2.5  Iris-virginica
# 102        7.1          3.0        5.9          2.1  Iris-virginica
# 104        6.5          3.0        5.8          2.2  Iris-virginica
# 105        7.6          3.0        6.6          2.1  Iris-virginica
# 107        7.3          2.9        6.3          1.8  Iris-virginica
# 108        6.7          2.5        5.8          1.8  Iris-virginica
# 109        7.2          3.6        6.1          2.5  Iris-virginica
# 117        7.7          3.8        6.7          2.2  Iris-virginica
# 118        7.7          2.6        6.9          2.3  Iris-virginica
# 120        6.9          3.2        5.7          2.3  Iris-virginica
# 122        7.7          2.8        6.7          2.0  Iris-virginica
# 124        6.7          3.3        5.7          2.1  Iris-virginica
# 125        7.2          3.2        6.0          1.8  Iris-virginica
# ...

# %%
grouped=df.groupby(df.species,as_index=False)
petlen_mean_by_species=grouped.aggregate(pd.DataFrame.mean)
merged=pd.merge(df,petlen_mean_by_species,on='species')

# %%
merged
# Out:
#      sepal_len_x  sepal_width_x  petal_len_x  petal_width_x         species  \
# 0            5.1            3.5          1.4            0.2     Iris-setosa
# 1            4.9            3.0          1.4            0.2     Iris-setosa
# 2            4.7            3.2          1.3            0.2     Iris-setosa
# 3            4.6            3.1          1.5            0.2     Iris-setosa
# 4            5.0            3.6          1.4            0.2     Iris-setosa
# 5            5.4            3.9          1.7            0.4     Iris-setosa
# 6            4.6            3.4          1.4            0.3     Iris-setosa
# 7            5.0            3.4          1.5            0.2     Iris-setosa
# 8            4.4            2.9          1.4            0.2     Iris-setosa
# 9            4.9            3.1          1.5            0.1     Iris-setosa
# 10           5.4            3.7          1.5            0.2     Iris-setosa
# ...

# %%
grouped

# %%
print(merged[merged.petal_len_x > 1.5 * merged.petal_len_y])
# Out:
# Empty DataFrame
# Columns: [sepal_len_x, sepal_width_x, petal_len_x, petal_width_x, species, sepal_len_y, sepal_width_y, petal_len_y, petal_width_y]
# Index: []

# %%
for species,dataframe in df.groupby(df[species]):
    print(df[df.petal_len > 1.5 * avgpl])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-dc1c9d144fd4> in <module>
# ----> 1 for species,dataframe in df.groupby(df[species]):
#       2     print(df[df.petal_len > 1.5 * avgpl])
#
# NameError: name 'species' is not defined

# %%
import scipy.cluster.hierarchy as shc

# %%
customer_data=df

# %%
x=customer_data.drop('species',axis=1)
plt.figure(figsize=(10,7))
plt.title('Customer dendogram')
dcnd=shc.dendogram(shc.linkage(x,method='complete')
import matplotlib.pyplot as plt
plt.show()
# Out:
#   File "<ipython-input-19-b9f886a658c8>", line 5
#     import matplotlib.pyplot as plt
#          ^
# SyntaxError: invalid syntax

# %%
#hierarchial sructure
import matplotlib.pyplot as plt
import pandas as pd 
import scipy.cluster.hierarchy as shc
customer_data =df
x=customer_data.drop('species',axis=1)
print(x)
plt.figure(figsize=(10, 7))
plt.title("Customer Dendograms")
dend = shc.dendrogram(shc.linkage(x, method='complete'))
plt.show()
# Out:
#      sepal_len  sepal_width  petal_len  petal_width
# 0          5.1          3.5        1.4          0.2
# 1          4.9          3.0        1.4          0.2
# 2          4.7          3.2        1.3          0.2
# 3          4.6          3.1        1.5          0.2
# 4          5.0          3.6        1.4          0.2
# 5          5.4          3.9        1.7          0.4
# 6          4.6          3.4        1.4          0.3
# 7          5.0          3.4        1.5          0.2
# 8          4.4          2.9        1.4          0.2
# 9          4.9          3.1        1.5          0.1
# 10         5.4          3.7        1.5          0.2
# 11         4.8          3.4        1.6          0.2
# 12         4.8          3.0        1.4          0.1
# 13         4.3          3.0        1.1          0.1
# 14         5.8          4.0        1.2          0.2
# 15         5.7          4.4        1.5          0.4
# 16         5.4          3.9        1.3          0.4
# ...
